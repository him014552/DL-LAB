# %% [markdown]
# # **Experiment No : 8**

# %% [markdown]
# **Q1. Given a sequence of alphabets (with some missing values), use an RNN and a
# Bidirectional RNN model to predict the missing values in the sequence.**

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random

# Define note mapping (Swara to numerical representation)
NOTE_TO_INT = {
    'Sa': 0,
    'Re': 1,
    'Ga': 2,
    'Ma': 3,
    'Pa': 4,
    'Dha': 5,
    'Ni': 6,
    'Sha': 7  # Higher octave Sa
}

INT_TO_NOTE = {i: note for note, i in NOTE_TO_INT.items()}

# Define raga specific patterns
RAGA_DEFINITIONS = {
    'Bhairav': {
        'aroha': ['Sa', 'Re', 'Ga', 'Ma', 'Pa', 'Dha', 'Ni', 'Sha'],
        'avaroha': ['Sha', 'Ni', 'Dha', 'Pa', 'Ma', 'Ga', 'Re', 'Sa'],
        'pakad': ['Sa', 'Re', 'Ga', 'Pa', 'Ma', 'Dha', 'Pa', 'Sa'],
        'characteristic': [
            'Sa', 'Re', 'Sa', 'Ga', 'Re', 'Sa',
            'Ma', 'Ga', 'Re', 'Sa', 'Ni', 'Sa'
        ]
    },
    'Bhopali': {
        'aroha': ['Sa', 'Re', 'Ga', 'Pa', 'Dha', 'Sha'],
        'avaroha': ['Sha', 'Dha', 'Pa', 'Ga', 'Re', 'Sa'],
        'pakad': ['Ga', 'Re', 'Sa', 'Re', 'Ga', 'Pa', 'Dha', 'Pa'],
        'characteristic': [
            'Ga', 'Re', 'Ga', 'Pa', 'Ga', 'Pa', 'Dha', 'Pa',
            'Ga', 'Re', 'Sa'
        ]
    },
    'Bageshree': {
        'aroha': ['Sa', 'Re', 'Ga', 'Ma', 'Pa', 'Dha', 'Ni', 'Sha'],
        'avaroha': ['Sha', 'Ni', 'Dha', 'Pa', 'Ma', 'Ga', 'Re', 'Sa'],
        'pakad': ['Ma', 'Ga', 'Sa', 'Ni', 'Dha', 'Pa', 'Ma', 'Ga'],
        'characteristic': [
            'Pa', 'Ma', 'Ga', 'Ma', 'Ga', 'Re', 'Sa', 'Ni',
            'Dha', 'Pa', 'Ma', 'Ga'
        ]
    }
}

class RagaSequenceGenerator:
    def __init__(self, raga_name, sequence_length=16):
        """
        Initialize Raga Sequence Generator

        Args:
            raga_name (str): Name of the raga ('Bhairav', 'Bhopali', or 'Bageshree')
            sequence_length (int): Length of input sequences for prediction
        """
        self.raga_name = raga_name
        self.sequence_length = sequence_length
        self.model = None
        self.n_notes = len(NOTE_TO_INT)

        if raga_name not in RAGA_DEFINITIONS:
            raise ValueError(f"Raga {raga_name} is not defined in the system")

        self.raga_definition = RAGA_DEFINITIONS[raga_name]

    def generate_training_data(self, num_sequences=500, max_seq_len=64):
        """
        Generate synthetic training data based on raga definition

        Args:
            num_sequences (int): Number of sequences to generate
            max_seq_len (int): Maximum length of generated sequences

        Returns:
            list: List of note sequences
        """
        sequences = []

        # Use the raga definition to create training sequences
        for _ in range(num_sequences):
            # Start with a random pattern from the raga definition
            pattern_types = ['aroha', 'avaroha', 'pakad', 'characteristic']
            pattern_weights = [0.25, 0.25, 0.3, 0.2]  # More focus on pakads

            # Create sequence by combining various patterns
            sequence = []
            seq_len = random.randint(self.sequence_length + 1, max_seq_len)

            while len(sequence) < seq_len:
                pattern_type = random.choices(pattern_types, weights=pattern_weights)[0]
                pattern = self.raga_definition[pattern_type].copy()

                # Sometimes reverse the pattern
                if random.random() < 0.2 and pattern_type in ['aroha', 'avaroha']:
                    pattern = pattern[::-1]

                # Sometimes take a subsequence
                if random.random() < 0.3 and len(pattern) > 4:
                    start = random.randint(0, len(pattern) - 4)
                    end = random.randint(start + 3, len(pattern))
                    pattern = pattern[start:end]

                sequence.extend(pattern)

            # Trim to max length
            sequence = sequence[:seq_len]
            sequences.append(sequence)

        return sequences

    def prepare_sequences(self, note_sequences):
        """
        Prepare sequences for training the model

        Args:
            note_sequences (list): List of note sequences

        Returns:
            tuple: (X, y) training data
        """
        X = []
        y = []

        for sequence in note_sequences:
            # Convert notes to integers
            int_sequence = [NOTE_TO_INT[note] for note in sequence]

            # Create input-output pairs
            for i in range(len(int_sequence) - self.sequence_length):
                X.append(int_sequence[i:i + self.sequence_length])
                y.append(int_sequence[i + self.sequence_length])

        # Convert to numpy arrays
        X = np.array(X)
        y = np.array(y)

        # One-hot encode the outputs
        y = to_categorical(y, num_classes=self.n_notes)

        return X, y

    def build_model(self):
        """
        Build the RNN model architecture
        """
        self.model = Sequential([
            LSTM(256, input_shape=(self.sequence_length, 1), return_sequences=True),
            Dropout(0.3),
            LSTM(256),
            Dropout(0.3),
            Dense(128, activation='relu'),
            Dense(self.n_notes, activation='softmax')
        ])

        self.model.compile(
            loss='categorical_crossentropy',
            optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
            metrics=['accuracy']
        )

        print(self.model.summary())

    def train(self, X, y, epochs=100, batch_size=64, validation_split=0.15):
        """
        Train the model on prepared sequences

        Args:
            X (numpy.ndarray): Input sequences
            y (numpy.ndarray): Target outputs (one-hot encoded)
            epochs (int): Number of training epochs
            batch_size (int): Batch size for training
            validation_split (float): Fraction of data to use for validation

        Returns:
            History object from model training
        """
        # Reshape X to be [samples, time steps, features]
        X = np.reshape(X, (X.shape[0], X.shape[1], 1))

        # Define callbacks
        callbacks = [
            tf.keras.callbacks.EarlyStopping(
                monitor='val_loss',
                patience=5,
                restore_best_weights=True
            ),
            tf.keras.callbacks.ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=3,
                min_lr=0.00001
            )
        ]

        # Train the model
        history = self.model.fit(
            X, y,
            batch_size=batch_size,
            epochs=epochs,
            validation_split=validation_split,
            callbacks=callbacks
        )

        return history

    def plot_training_history(self, history):
        """
        Plot the training history

        Args:
            history: Training history object
        """
        plt.figure(figsize=(12, 5))

        # Plot accuracy
        plt.subplot(1, 2, 1)
        plt.plot(history.history['accuracy'], label='Training Accuracy')
        plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
        plt.title(f'Model Accuracy - {self.raga_name}')
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend()

        # Plot loss
        plt.subplot(1, 2, 2)
        plt.plot(history.history['loss'], label='Training Loss')
        plt.plot(history.history['val_loss'], label='Validation Loss')
        plt.title(f'Model Loss - {self.raga_name}')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend()

        plt.tight_layout()
        plt.savefig(f'{self.raga_name}_training_history.png')
        plt.show()

    def generate_sequence(self, seed_sequence=None, sequence_length=32, temperature=0.8):
        """
        Generate a new sequence using the trained model

        Args:
            seed_sequence (list): Optional seed sequence (if None, a random one is chosen)
            sequence_length (int): Length of sequence to generate
            temperature (float): Controls randomness (lower = more conservative)

        Returns:
            list: Generated sequence of notes
        """
        if self.model is None:
            raise ValueError("Model has not been trained yet")

        # Create seed sequence if not provided
        if seed_sequence is None:
            # Use a random snippet from the raga's characteristic pattern
            seed_sequence = self.raga_definition['characteristic'][:self.sequence_length]

            # If characteristic pattern is shorter than sequence_length, pad with aroha
            if len(seed_sequence) < self.sequence_length:
                seed_sequence = (seed_sequence + self.raga_definition['aroha'] * 3)[:self.sequence_length]

        # Ensure seed sequence is exactly sequence_length
        if len(seed_sequence) > self.sequence_length:
            seed_sequence = seed_sequence[:self.sequence_length]
        elif len(seed_sequence) < self.sequence_length:
            # Pad with repeating pattern if needed
            while len(seed_sequence) < self.sequence_length:
                seed_sequence.append(random.choice(self.raga_definition['aroha']))

        # Convert seed sequence to integers
        int_seed = [NOTE_TO_INT[note] for note in seed_sequence]

        # Generated sequence starts with the seed
        generated_sequence = list(int_seed)

        # Generate new notes
        for _ in range(sequence_length):
            # Prepare input for prediction
            x = np.reshape(generated_sequence[-self.sequence_length:], (1, self.sequence_length, 1))

            # Predict next note
            prediction = self.model.predict(x, verbose=0)[0]

            # Apply temperature to prediction
            prediction = np.log(prediction + 1e-10) / temperature
            prediction = np.exp(prediction) / np.sum(np.exp(prediction))

            # Sample from the prediction distribution
            next_index = np.random.choice(len(prediction), p=prediction)

            # Add the new note to the generated sequence
            generated_sequence.append(next_index)

        # Convert back to note names
        generated_notes = [INT_TO_NOTE[idx] for idx in generated_sequence[self.sequence_length:]]

        return generated_notes

    def save_model(self, filepath):
        """Save the trained model to a file"""
        if self.model is None:
            raise ValueError("No model to save")
        self.model.save(filepath)
        print(f"Model saved to {filepath}")

    def load_model(self, filepath):
        """Load a trained model from a file"""
        self.model = tf.keras.models.load_model(filepath)
        print(f"Model loaded from {filepath}")


def main():
    # Example usage
    raga_name = 'Bhairav'  # Can be 'Bhairav', 'Bhopali', or 'Bageshree'

    # Initialize the generator
    generator = RagaSequenceGenerator(raga_name, sequence_length=16)

    # Generate training data
    print(f"Generating training data for Raga {raga_name}...")
    note_sequences = generator.generate_training_data(num_sequences=500)

    # Prepare sequences for training
    X, y = generator.prepare_sequences(note_sequences)
    print(f"Prepared {len(X)} training samples")

    # Build and train the model
    generator.build_model()
    print("Training model...")
    history = generator.train(X, y, epochs=50)

    # Plot training history
    generator.plot_training_history(history)

    # Generate and display a new sequence
    print("\nGenerating new sequence...")
    generated_sequence = generator.generate_sequence(sequence_length=32)
    print("Generated sequence:")
    print(' '.join(generated_sequence))

    # Save the model
    generator.save_model(f"raga_{raga_name.lower()}_model.h5")

    # Generate examples for multiple ragas
    print("\nGenerating examples for multiple ragas:")
    for raga in ['Bhairav', 'Bhopali', 'Bageshree']:
        if raga != raga_name:
            print(f"\nTraining model for Raga {raga}...")
            raga_gen = RagaSequenceGenerator(raga, sequence_length=16)
            sequences = raga_gen.generate_training_data(num_sequences=300)  # Smaller dataset for example
            X, y = raga_gen.prepare_sequences(sequences)
            raga_gen.build_model()
            raga_gen.train(X, y, epochs=30)  # Shorter training for example

            generated = raga_gen.generate_sequence(sequence_length=24)
            print(f"Generated {raga} sequence:")
            print(' '.join(generated))


if __name__ == "__main__":
    main()
# Out:
# Generating training data for Raga Bhairav...
# Prepared 11956 training samples
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 16, 256)             │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │           1,032 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 823,432 (3.14 MB)
#  Trainable params: 823,432 (3.14 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Training model...
# Epoch 1/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.2196 - loss: 1.9695 - val_accuracy: 0.4047 - val_loss: 1.5718 - learning_rate: 0.0010
# Epoch 2/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.4919 - loss: 1.3415 - val_accuracy: 0.6951 - val_loss: 0.9346 - learning_rate: 0.0010
# Epoch 3/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7433 - loss: 0.8055 - val_accuracy: 0.7542 - val_loss: 0.7401 - learning_rate: 0.0010
# Epoch 4/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7952 - loss: 0.6410 - val_accuracy: 0.7854 - val_loss: 0.6471 - learning_rate: 0.0010
# Epoch 5/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8133 - loss: 0.5607 - val_accuracy: 0.7971 - val_loss: 0.6050 - learning_rate: 0.0010
# Epoch 6/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8261 - loss: 0.5188 - val_accuracy: 0.8060 - val_loss: 0.5861 - learning_rate: 0.0010
# Epoch 7/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8380 - loss: 0.4697 - val_accuracy: 0.7971 - val_loss: 0.5868 - learning_rate: 0.0010
# Epoch 8/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8477 - loss: 0.4610 - val_accuracy: 0.8066 - val_loss: 0.5727 - learning_rate: 0.0010
# Epoch 9/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8389 - loss: 0.4592 - val_accuracy: 0.8138 - val_loss: 0.5691 - learning_rate: 0.0010
# Epoch 10/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8424 - loss: 0.4570 - val_accuracy: 0.8105 - val_loss: 0.5858 - learning_rate: 0.0010
# Epoch 11/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8469 - loss: 0.4441 - val_accuracy: 0.8211 - val_loss: 0.5749 - learning_rate: 0.0010
# Epoch 12/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8459 - loss: 0.4297 - val_accuracy: 0.8233 - val_loss: 0.5597 - learning_rate: 0.0010
# Epoch 13/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8510 - loss: 0.4268 - val_accuracy: 0.8250 - val_loss: 0.5693 - learning_rate: 0.0010
# Epoch 14/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8476 - loss: 0.4246 - val_accuracy: 0.8266 - val_loss: 0.5578 - learning_rate: 0.0010
# Epoch 15/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8606 - loss: 0.4095 - val_accuracy: 0.8183 - val_loss: 0.5527 - learning_rate: 0.0010
# Epoch 16/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8490 - loss: 0.4234 - val_accuracy: 0.8172 - val_loss: 0.5677 - learning_rate: 0.0010
# Epoch 17/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8604 - loss: 0.3987 - val_accuracy: 0.8038 - val_loss: 0.5563 - learning_rate: 0.0010
# Epoch 18/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8613 - loss: 0.3918 - val_accuracy: 0.8211 - val_loss: 0.5581 - learning_rate: 0.0010
# Epoch 19/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8642 - loss: 0.3819 - val_accuracy: 0.8266 - val_loss: 0.5610 - learning_rate: 5.0000e-04
# Epoch 20/50
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8659 - loss: 0.3716 - val_accuracy: 0.8305 - val_loss: 0.5597 - learning_rate: 5.0000e-04
# Generating new sequence...
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Generated sequence:
# Pa Dha Ni Sha Sa Re Ga Pa Ma Dha Pa Sa Sa Re Sa Ga Re Sa Ma Ga Re Sa Ni Sa Sa Re Ga Pa Ma Dha Pa Sa
# Model saved to raga_bhairav_model.h5
#
# Generating examples for multiple ragas:
#
# Training model for Raga Bhopali...
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 16, 256)             │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_3 (LSTM)                        │ (None, 256)                 │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │           1,032 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 823,432 (3.14 MB)
#  Trainable params: 823,432 (3.14 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.2510 - loss: 1.7559 - val_accuracy: 0.3315 - val_loss: 1.5351 - learning_rate: 0.0010
# Epoch 2/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3868 - loss: 1.4592 - val_accuracy: 0.6667 - val_loss: 0.9968 - learning_rate: 0.0010
# Epoch 3/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6583 - loss: 0.9624 - val_accuracy: 0.7567 - val_loss: 0.7367 - learning_rate: 0.0010
# Epoch 4/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7440 - loss: 0.7503 - val_accuracy: 0.7874 - val_loss: 0.6391 - learning_rate: 0.0010
# Epoch 5/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7911 - loss: 0.6342 - val_accuracy: 0.7902 - val_loss: 0.5919 - learning_rate: 0.0010
# Epoch 6/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8045 - loss: 0.5691 - val_accuracy: 0.8134 - val_loss: 0.5593 - learning_rate: 0.0010
# Epoch 7/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8116 - loss: 0.5350 - val_accuracy: 0.8124 - val_loss: 0.5473 - learning_rate: 0.0010
# Epoch 8/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8248 - loss: 0.5103 - val_accuracy: 0.8134 - val_loss: 0.5151 - learning_rate: 0.0010
# Epoch 9/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8141 - loss: 0.5207 - val_accuracy: 0.8162 - val_loss: 0.5181 - learning_rate: 0.0010
# Epoch 10/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8260 - loss: 0.4750 - val_accuracy: 0.8208 - val_loss: 0.4991 - learning_rate: 0.0010
# Epoch 11/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8289 - loss: 0.4643 - val_accuracy: 0.8329 - val_loss: 0.4838 - learning_rate: 0.0010
# Epoch 12/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8374 - loss: 0.4388 - val_accuracy: 0.8375 - val_loss: 0.4739 - learning_rate: 0.0010
# Epoch 13/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8441 - loss: 0.4412 - val_accuracy: 0.8292 - val_loss: 0.4787 - learning_rate: 0.0010
# Epoch 14/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8313 - loss: 0.4657 - val_accuracy: 0.8347 - val_loss: 0.4694 - learning_rate: 0.0010
# Epoch 15/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8434 - loss: 0.4489 - val_accuracy: 0.8273 - val_loss: 0.4633 - learning_rate: 0.0010
# Epoch 16/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8416 - loss: 0.4343 - val_accuracy: 0.8403 - val_loss: 0.4604 - learning_rate: 0.0010
# Epoch 17/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8419 - loss: 0.4203 - val_accuracy: 0.8375 - val_loss: 0.4621 - learning_rate: 0.0010
# Epoch 18/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8476 - loss: 0.4271 - val_accuracy: 0.8366 - val_loss: 0.4582 - learning_rate: 0.0010
# Epoch 19/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8416 - loss: 0.4178 - val_accuracy: 0.8440 - val_loss: 0.4534 - learning_rate: 0.0010
# Epoch 20/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8387 - loss: 0.4306 - val_accuracy: 0.8449 - val_loss: 0.4510 - learning_rate: 0.0010
# Epoch 21/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8465 - loss: 0.4181 - val_accuracy: 0.8245 - val_loss: 0.4637 - learning_rate: 0.0010
# Epoch 22/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8505 - loss: 0.3937 - val_accuracy: 0.8329 - val_loss: 0.4580 - learning_rate: 0.0010
# Epoch 23/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8508 - loss: 0.3985 - val_accuracy: 0.8384 - val_loss: 0.4539 - learning_rate: 0.0010
# Epoch 24/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8489 - loss: 0.3856 - val_accuracy: 0.8412 - val_loss: 0.4525 - learning_rate: 5.0000e-04
# Epoch 25/30
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8637 - loss: 0.3654 - val_accuracy: 0.8273 - val_loss: 0.4613 - learning_rate: 5.0000e-04
# Generated Bhopali sequence:
# Sha Ga Re Sa Re Ga Pa Dha Pa Ga Re Sa Re Ga Pa Dha Pa Sha Dha Pa Ga Re Sa Sa
#
# Training model for Raga Bageshree...
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                        │ (None, 16, 256)             │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 16, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_5 (LSTM)                        │ (None, 256)                 │         525,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 8)                   │           1,032 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 823,432 (3.14 MB)
#  Trainable params: 823,432 (3.14 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.1828 - loss: 2.0239 - val_accuracy: 0.2299 - val_loss: 1.8808 - learning_rate: 0.0010
# Epoch 2/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.3082 - loss: 1.7604 - val_accuracy: 0.5239 - val_loss: 1.3198 - learning_rate: 0.0010
# Epoch 3/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6230 - loss: 1.1231 - val_accuracy: 0.7619 - val_loss: 0.8015 - learning_rate: 0.0010
# Epoch 4/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7547 - loss: 0.7867 - val_accuracy: 0.8079 - val_loss: 0.6264 - learning_rate: 0.0010
# Epoch 5/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8068 - loss: 0.6372 - val_accuracy: 0.8161 - val_loss: 0.5598 - learning_rate: 0.0010
# Epoch 6/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8216 - loss: 0.5712 - val_accuracy: 0.8215 - val_loss: 0.5593 - learning_rate: 0.0010
# Epoch 7/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8323 - loss: 0.5303 - val_accuracy: 0.8323 - val_loss: 0.4980 - learning_rate: 0.0010
# Epoch 8/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8380 - loss: 0.5041 - val_accuracy: 0.8332 - val_loss: 0.4989 - learning_rate: 0.0010
# Epoch 9/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8350 - loss: 0.5042 - val_accuracy: 0.8440 - val_loss: 0.4695 - learning_rate: 0.0010
# Epoch 10/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8465 - loss: 0.4643 - val_accuracy: 0.8359 - val_loss: 0.4719 - learning_rate: 0.0010
# Epoch 11/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8491 - loss: 0.4488 - val_accuracy: 0.8476 - val_loss: 0.4578 - learning_rate: 0.0010
# Epoch 12/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8553 - loss: 0.4413 - val_accuracy: 0.8440 - val_loss: 0.4668 - learning_rate: 0.0010
# Epoch 13/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8491 - loss: 0.4534 - val_accuracy: 0.8521 - val_loss: 0.4502 - learning_rate: 0.0010
# Epoch 14/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8555 - loss: 0.4303 - val_accuracy: 0.8467 - val_loss: 0.4637 - learning_rate: 0.0010
# Epoch 15/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8624 - loss: 0.4153 - val_accuracy: 0.8476 - val_loss: 0.4586 - learning_rate: 0.0010
# Epoch 16/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8600 - loss: 0.4003 - val_accuracy: 0.8377 - val_loss: 0.4849 - learning_rate: 0.0010
# Epoch 17/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8639 - loss: 0.3858 - val_accuracy: 0.8566 - val_loss: 0.4497 - learning_rate: 5.0000e-04
# Epoch 18/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8697 - loss: 0.3774 - val_accuracy: 0.8584 - val_loss: 0.4489 - learning_rate: 5.0000e-04
# Epoch 19/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8598 - loss: 0.3850 - val_accuracy: 0.8539 - val_loss: 0.4469 - learning_rate: 5.0000e-04
# Epoch 20/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8692 - loss: 0.3912 - val_accuracy: 0.8530 - val_loss: 0.4420 - learning_rate: 5.0000e-04
# Epoch 21/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8748 - loss: 0.3476 - val_accuracy: 0.8530 - val_loss: 0.4533 - learning_rate: 5.0000e-04
# Epoch 22/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8611 - loss: 0.3909 - val_accuracy: 0.8575 - val_loss: 0.4488 - learning_rate: 5.0000e-04
# Epoch 23/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8758 - loss: 0.3578 - val_accuracy: 0.8548 - val_loss: 0.4547 - learning_rate: 5.0000e-04
# Epoch 24/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8701 - loss: 0.3539 - val_accuracy: 0.8512 - val_loss: 0.4496 - learning_rate: 2.5000e-04
# Epoch 25/30
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8743 - loss: 0.3496 - val_accuracy: 0.8557 - val_loss: 0.4524 - learning_rate: 2.5000e-04
# Generated Bageshree sequence:
# Pa Dha Ni Sha Ma Ga Sa Ni Dha Pa Ma Ga Sa Re Ga Ma Pa Dha Ni Sha Ma Ga Sa Ni

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Define notes in Indian classical music
notes = ["Sa", "Re", "Ga", "Ma", "Pa", "Dha", "Ni", "Sha"]

# Generate more artificial sequences for training
raga_sequences = []

# Raga Bhairav (Sa Re Ga Ma Pa Dha Ni Sha)
for _ in range(200):
    raga_sequences.append(["Sa", "Re", "Ga", "Ma", "Pa", "Dha", "Ni", "Sha"])
    raga_sequences.append(["Sha", "Ni", "Dha", "Pa", "Ma", "Ga", "Re", "Sa"])

# Raga Bhopali (Sa Re Ga Pa Dha Sha)
for _ in range(200):
    raga_sequences.append(["Sa", "Re", "Ga", "Pa", "Dha", "Sha"])
    raga_sequences.append(["Sha", "Dha", "Pa", "Ga", "Re", "Sa"])

# Raga Bageshree (Sa Ga Ma Dha Ni Sha)
for _ in range(200):
    raga_sequences.append(["Sa", "Ga", "Ma", "Dha", "Ni", "Sha"])
    raga_sequences.append(["Sha", "Ni", "Dha", "Ma", "Ga", "Sa"])

# Tokenize the notes
tokenizer = Tokenizer()
tokenizer.fit_on_texts(raga_sequences)
sequences = tokenizer.texts_to_sequences(raga_sequences)

# Prepare training data
X, y = [], []
for seq in sequences:
    for i in range(1, len(seq)):
        X.append(seq[:i])
        y.append(seq[i])

X = pad_sequences(X, padding='pre')
y = np.array(y)

# Build the improved RNN model
model = Sequential([
    Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=50, input_length=X.shape[1]),
    Bidirectional(LSTM(128, return_sequences=True)),
    Dropout(0.2),
    LSTM(128),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dense(len(tokenizer.word_index) + 1, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=50, verbose=1, batch_size=32)

# Generate a sequence
def generate_sequence(seed_text, length=10):
    sequence = tokenizer.texts_to_sequences([seed_text.split()])[0]
    for _ in range(length):
        padded_sequence = pad_sequences([sequence], maxlen=X.shape[1], padding='pre')
        predicted_index = np.argmax(model.predict(padded_sequence, verbose=0))
        sequence.append(predicted_index)
    return ' '.join([tokenizer.index_word[i] for i in sequence if i in tokenizer.index_word])

# Example: Generate notes from "Sa Re"
print("Generated Raga Sequence:", generate_sequence("Sa Re", length=8))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.3752 - loss: 1.5301
# Epoch 2/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8407 - loss: 0.3147
# Epoch 3/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8806 - loss: 0.2198
# Epoch 4/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8681 - loss: 0.2168
# Epoch 5/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8831 - loss: 0.2016
# Epoch 6/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8773 - loss: 0.2099
# Epoch 7/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8721 - loss: 0.2479
# Epoch 8/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8767 - loss: 0.2021
# Epoch 9/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8839 - loss: 0.1965
# Epoch 10/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8769 - loss: 0.2060
# Epoch 11/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8764 - loss: 0.1980
# Epoch 12/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8840 - loss: 0.1972
# Epoch 13/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8863 - loss: 0.1916
# Epoch 14/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8835 - loss: 0.1919
# Epoch 15/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8875 - loss: 0.1968
# Epoch 16/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8786 - loss: 0.2011
# Epoch 17/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8809 - loss: 0.1947
# Epoch 18/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8835 - loss: 0.1944
# Epoch 19/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8863 - loss: 0.1969
# Epoch 20/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8855 - loss: 0.1979
# Epoch 21/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8242 - loss: 0.4390
# Epoch 22/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8769 - loss: 0.2087
# Epoch 23/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8808 - loss: 0.1979
# Epoch 24/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8790 - loss: 0.2022
# Epoch 25/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8823 - loss: 0.1987
# Epoch 26/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8833 - loss: 0.1962
# Epoch 27/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8852 - loss: 0.1942
# Epoch 28/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8758 - loss: 0.1985
# Epoch 29/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8814 - loss: 0.1974
# Epoch 30/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8824 - loss: 0.1940
# Epoch 31/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8781 - loss: 0.2009
# Epoch 32/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8857 - loss: 0.1975
# Epoch 33/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8803 - loss: 0.1974
# Epoch 34/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8815 - loss: 0.1965
# Epoch 35/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8787 - loss: 0.2010
# Epoch 36/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8853 - loss: 0.1935
# Epoch 37/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8761 - loss: 0.1994
# Epoch 38/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8834 - loss: 0.1951
# Epoch 39/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8821 - loss: 0.1975
# Epoch 40/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8834 - loss: 0.1962
# Epoch 41/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8810 - loss: 0.1966
# Epoch 42/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8845 - loss: 0.1947
# Epoch 43/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8858 - loss: 0.1949
# Epoch 44/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8815 - loss: 0.1944
# Epoch 45/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8785 - loss: 0.1936
# Epoch 46/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8792 - loss: 0.1972
# Epoch 47/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8824 - loss: 0.1999
# Epoch 48/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8836 - loss: 0.1921
# Epoch 49/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8770 - loss: 0.1991
# Epoch 50/50
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8715 - loss: 0.2391
# Generated Raga Sequence: sa re ga ma pa dha sha dha re sha
